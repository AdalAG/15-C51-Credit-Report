# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

df = pd.read_csv("credit_approval/credit_approval.csv")

# %%
# count missing values 
for c in df.columns:
    print(f"Number of {c} missing value:", sum(df[c].isna()))
# Out:
# Number of A1 missing value: 12
# Number of A2 missing value: 12
# Number of A3 missing value: 0
# Number of A4 missing value: 6
# Number of A5 missing value: 6
# Number of A6 missing value: 9
# Number of A7 missing value: 9
# Number of A8 missing value: 0
# Number of A9 missing value: 0
# Number of A10 missing value: 0
# Number of A11 missing value: 0
# Number of A12 missing value: 0
# Number of A13 missing value: 0
# Number of A14 missing value: 13
# Number of A15 missing value: 0
# Number of A16 missing value: 0
